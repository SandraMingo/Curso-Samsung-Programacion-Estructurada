# %% [markdown]
# # Título
# ## Subtítulo
# ### Cabecera 1
# #### Cabecera 2
#
# Esto es un notebook de ejemplo.
#
# Este es el segundo párrafo.
#
# Esto está en **negrita**.
#
# Esto está en _cursiva_.
#
# Esto está en `monoespaciado`.
#
# Para ejecutar una celda, pulsar `ctr intro`.
#
# Para borrar una celda, pulsar dos veces la `D` (_delete_).
#
# Lista de ciudades a visitar:
# - Barcelona
# - París
# - Londres
# - Roma
# - Berlín
#
# Lista numerada:
# 1. Primero
# 2. Segundo
# 3. Tercero
#
# [Aula virtual](https://ensenanzaspropias.cv.uma.es/course/view.php?id=5719)
#
# Cómo crear una tabla en markdown:
#
# | Ciudad | Prefijo |
# |--------|---------|
# |Málaga  | 952     |
# |Madrid  | 91      |
# |Las Palmas | 928  |
# |Sevilla | 954     |
#
# Introducir ecuaciones mediante LaTex. El área de un círculo de radio $r$ es $A = \pi r^2$
#
# El volumen $V$ de una esfera de radio $r$ es:
# $$V = \frac{4}{3}\pi r^3$$

# %% [markdown]
# # Esto es un título (= h1)
#
# ## Esto es un subtítulo (= h2)
#
# #### Esta es una cabecera de nivel 4 (h4)
#
# Esto es un notebook de ejemplo. Esta es la segunda línea del párrafo.
#
# Este es el segundo párrafo.
#
# Esto está en **negrita**.
#
# Esto está en _cursiva_.
#
# Esto es `monoespaciado`.
#
# Para ejecutar una celda pulsar `Ctrl-Intro`.
#
# Para borrar una celda pulsar dos veces la `D (D-D)` (_delete_).
#
# Lista de ciudades a visitar:
# - Madrid
# - París
# - Londres
# - Roma
# - Venecia
#
# Lista numerada:
# 1. Primero
# 1. Primero y medio
# 1. Segundo
# 1. Tercero
#
#
# [Home page de python](https://www.python.org/)
#
# Cómo crear una tabla en markdown:
#
# | Ciudad | Prefijo |
# |--------|---------|
# | Málaga | 952     |
# | Madrid | 91      |
# | Las Palmas | 928 |
# | Sevilla | 954 |
#
# Introducir ecuaciones, utilizamos LaTeX. El área de un círculo de radio $r$ es $A = \pi r^2$.
#
# El volumen $V$ de una esfera de radio $r$ es:
# $$
# V = \frac{4}{3} \pi r^3
# $$
